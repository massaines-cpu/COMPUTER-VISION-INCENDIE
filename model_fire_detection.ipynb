# %% [markdown]
# # Fine-tuning YOLO fire detection

# %%
# !pip install ultralytics
# Out:
# ...
#   Using cached numpy-2.4.3-cp314-cp314-macosx_14_0_arm64.whl.metadata (6.6 kB)
# ...
#   Using cached matplotlib-3.10.8-cp314-cp314-macosx_11_0_arm64.whl.metadata (52 kB)
# ...
#   Using cached pillow-12.1.1-cp314-cp314-macosx_11_0_arm64.whl.metadata (8.8 kB)
# ...
#   Using cached scipy-1.17.1-cp314-cp314-macosx_14_0_arm64.whl.metadata (62 kB)
# ...
#   Using cached torch-2.10.0-cp314-cp314-macosx_14_0_arm64.whl.metadata (31 kB)
# ...
#   Using cached contourpy-1.3.3-cp314-cp314-macosx_11_0_arm64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.62.1-cp314-cp314-macosx_10_15_universal2.whl.metadata (117 kB)
# ...
#   Using cached kiwisolver-1.5.0-cp314-cp314-macosx_11_0_arm64.whl.metadata (5.1 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# ...

# %%
import os
from google.colab import files
import zipfile
import yaml
from ultralytics import YOLO
import matplotlib.pyplot as plt
import torch
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# ## Chargement des données
# **OPTION 1** : si vous souhaitez passer par google drive
#
# --> Plus rapide pour charger les données au démarrage de la session

# %%
# connexion google drive à colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_1063/3128723017.py in <cell line: 0>()
#       1 # connexion google drive à colab
#       2 from google.colab import drive
# ----> 3 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
# ...

# %%
# décompression des data dans le dossier content/
# Mettre à jour le nom de votre archive
# !tar -xzf /content/drive/MyDrive/test.tar.gz -C /content/

# %% [markdown]
# **OU OPTION 2** : avec un fichier zip sans passer par google drive

# %%
# Upload du fichier zip
uploaded = files.upload()
zip_path = list(uploaded.keys())[0]

# Décompression dans 'datasets'
extract_dir = "datasets"
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
   zip_ref.extractall(extract_dir)

# %% [markdown]
# ## Entraînement du modèle

# %%
# TO UPDATE avec votre nom de dossier
yaml_path = "/content/test/data.yaml"

# Charger le modèle que vous souhaitez
model = YOLO("yolov8n.pt")

# TO DO compléter avec vos paramètres
results = model.train(
    data=yaml_path,
    save_period=5,
    epochs=,
    batch=,
    imgsz=)

# %% [markdown]
# ## Test
#
# Utilisation du modèle sur le jeu de test

# %%
test_results = model.val(data=yaml_path, split="test")
test_results.results_dict
